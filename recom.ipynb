# %%
import numpy as np
import pandas as pd
#from flask import Flask, render_template, request
# libraries for making count matrix and similarity matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import HTML

# %%
def create_sim():
    data = pd.read_csv('Recom.csv')
    # creating a count matrix
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(data['text'])
    # creating a similarity score matrix
    sim = cosine_similarity(count_matrix)
    return data,sim

# %%
def rcmd(m):
    #m = m.lower()
    # check if data and sim are already assigned
    try:
        data.head()
        sim.shape
    except:
        data, sim = create_sim()
    # check if the movie is in our database or not
    if m not in data['Job_Roles'].unique():
        return('This job_roles is not in our database.\nPlease check if you spelled it correct.')
    else:
        # getting the index of the movie in the dataframe
        i = data.loc[data['Job_Roles']==m].index[0]

        # fetching the row containing similarity scores of the movie
        # from similarity matrix and enumerate it
        lst = list(enumerate(sim[i]))

        # sorting this list in decreasing order based on the similarity score
        lst = sorted(lst, key = lambda x:x[1] ,reverse=True)

        # taking top 1- movie scores
        # not taking the first index since it is the same movie
        lst = lst[1:11]

        # making an empty list that will containg all 10 movie recommendations
        l = []
        L=[]
        for i in range(len(lst)):
            a = lst[i][0]
            l.append(data['skills'][a])
            L.append(data['Job_Roles'][a])
            jobs={'Roles':L,'TEXT':l}
            recommendation = pd.DataFrame(jobs)
            result = recommendation.to_html()
            
            html = recommendation.to_html()
            # write html to file 
            text_file = open("index.html", "w") 
            text_file.write(html) 
            text_file.close() 
            table=HTML(recommendation.to_html(classes='table table-striped'))
  

        return table

# %%
rcmd('Machine Learning Engineer')
# Out:
# <table border="1" class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Roles</th>
#       <th>TEXT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Analyst</td>
#       <td>Business Intelligence\nArtificial Intelligence\nNatural Language Processing\nNeural Networks\nData Mining\nMachine Learning\nDeep Learning\nSQL</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Machine Learning Engineer</td>
#       <td>NLP\nArtificial Intelligence\nNeural Networks\nText Mining\nMachine Learning Engineer\nSpacy\nMachine Learning\nDeep Learning</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Data Scientist</td>
#       <td>Robot Programming\nArtificial Intelligence\nNatural Language Processing\nNeural Networks\nMachine Learning\nStatistics\nDeep Learning\nPython</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Machine Learning Engineer</td>
#       <td>Computer vision\ndeep learning\nCoding\nNeural networks\nDjango\nMachine learning\nNatural language processing\nData analytics</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Machine Learning Engineer</td>
#       <td>Data Science\nR\nNLP\nArtificial Intelligence\nData Management\nMachine Learning\nPython\nPredictive Analytics</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Machine Learning Engineer</td>
#       <td>Nltk\nNLP\nArtificial Intelligence\nNeural Networks\nKnn\nText Mining\nSpacy\nMachine Learning</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Machine Learning Engineer</td>
#       <td>Predictive Modeling\nR\nData Scientist\nData Management\nMachine Learning\nPython\nSQL</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Machine Learning Engineer</td>
#       <td>data science\nMachine learning</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Machine Learning Engineer</td>
#       <td>Training\ndeep learning\nBackend\nMachine learning\nNatural language processing\nAnalytics\ninterview scheduling\nSQL</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Machine Learning Engineer</td>
#       <td>Data Science\nArtificial Intelligence\nMachine Learning\nPytorch\nTensorflow\nScipy\nNLP\nNatural Language Processing</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = recommendation.to_html() 
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-aae8b5ec511d> in <module>
# ----> 1 result = recommendation.to_html()
#       2 print(result)
#
# NameError: name 'recommendation' is not defined

# %%
data = pd.read_csv('Recom.csv')
data
# Out:
#                       Job_Roles  \
# 0                       Analyst
# 1     Machine Learning Engineer
# 2     Machine Learning Engineer
# 3                Data Scientist
# 4                Data Scientist
# ...                         ...
# 2681              Data Engineer
# 2682                 Researcher
# 2683                    Analyst
# 2684              Data Engineer
# 2685          Software Engineer
#
#                                                    text  avg_exp  \
# 0     analyst caia center artificial intelligence ad...      1.5
# 1     machine learn engineer carbynetech india hyder...      5.5
# 2     machine learn engineer carbynetech india hyder...      5.5
# 3     data scientist flipkart internet private limit...      4.5
# 4     data scientist groupon share service pvt ltd b...      6.0
# ...                                                 ...      ...
# 2681  data engineer talent corner service pvt ltd ah...      2.5
# 2682  researcher interactions karnataka train operat...      2.5
# 2683  analyst fusion analytics world chennai unix au...      4.5
# 2684  data engineer vacancieshub hrm solutions pvt l...      5.0
# 2685  software engineer uber hyderabad backend cod c...     10.0
#
#                   salary                            locations  \
# 0       350000 - 450000   Chennai, Pune, Bengaluru, Hyderabad
# 1          Not disclosed                            Hyderabad
# 2          Not disclosed                            Hyderabad
# 3          Not disclosed                            Bengaluru
# 4          Not disclosed                            Bengaluru
# ...                  ...                                  ...
# 2681    450000 - 550000                             Ahmedabad
# 2682       Not disclosed                            karnataka
# 2683       Not disclosed                              Chennai
# 2684  1200000 - 1600000                                 Kochi
# 2685       Not disclosed                            Hyderabad
#
#                                                  skills
# 0     Business Intelligence\nArtificial Intelligence...
# 1     Business Intelligence\nArtificial Intelligence...
# 2     Predictive Modeling\nR\nData Scientist\nData M...
# 3     Pytorch\nTensorflow\nData Science\nNLP\nAlgori...
# 4     Natural Language Processing\nMachine Learning\...
# ...                                                 ...
# 2681  Data dictionary\nreports\nRelational Databases...
# 2682  Training\nOperations research\nArtificial Inte...
# 2683  Unix\nAutomation\nSAS\nData management\nMIS\nA...
# 2684  ADF\nSAP\nBoomi\nData Engineer\nInformatica\nD...
# 2685  Backend\nCoding\nCloud Services\nSoftware Engi...
#
# [2686 rows x 6 columns]
